# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

# %%
base = Path().resolve().parent
file_path = f'{base}' + '/data/medicare_data_cleaned.parquet'

df = pd.read_parquet(file_path)

# %%
df_2023 = df[df['year']==2023]

df_2023 = df_2023.drop(columns=['Rndrng_Prvdr_St', 'Rndrng_Prvdr_State_FIPS',
                       'Tot_Dschrgs', 'Avg_Submtd_Cvrd_Chrg', 'Avg_Tot_Pymt_Amt', 'year'], axis=1)

# %%
df_2023.head()
# Out:
#      Rndrng_Prvdr_CCN            Rndrng_Prvdr_Org_Name Rndrng_Prvdr_City  \
# 2000           010001  Southeast Health Medical Center            Dothan
# 2001           010001  Southeast Health Medical Center            Dothan
# 2002           010001  Southeast Health Medical Center            Dothan
# 2003           010001  Southeast Health Medical Center            Dothan
# 2004           010001  Southeast Health Medical Center            Dothan
#
#       Rndrng_Prvdr_Zip5 Rndrng_Prvdr_State_Abrvtn DRG_Cd  Avg_Mdcr_Pymt_Amt  \
# 2000            36301.0                        AL    003      115544.142860
# 2001            36301.0                        AL    023       35261.807692
# 2002            36301.0                        AL    024       25048.916667
# 2003            36301.0                        AL    025       32438.625000
# 2004            36301.0                        AL    038        9579.363636
#
#            RUCA_category
# 2000  metro_high_commute
# 2001  metro_high_commute
# 2002  metro_high_commute
# 2003  metro_high_commute
# 2004  metro_high_commute

# %%
common_drgs = df_2023['DRG_Cd'].value_counts(
)[df_2023['DRG_Cd'].value_counts() > 25].index

df_2023['drg_grouped'] = df_2023['DRG_Cd'].apply(
    lambda x: x if x in common_drgs else 'Other')

# %%
cat_cols = ['Rndrng_Prvdr_CCN', 'DRG_Cd', 'Rndrng_Prvdr_Zip5', 'Rndrng_Prvdr_Org_Name',
            'Rndrng_Prvdr_City', 'Rndrng_Prvdr_State_Abrvtn', 'RUCA_category', 'drg_grouped']

# Encode each column
for col in cat_cols:
    df_2023[col] = df_2023[col].astype('category')

# %%
df_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 146427 entries, 2000 to 439168
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Rndrng_Prvdr_CCN           146427 non-null  category
#  1   Rndrng_Prvdr_Org_Name      146427 non-null  category
#  2   Rndrng_Prvdr_City          146427 non-null  category
#  3   Rndrng_Prvdr_Zip5          146427 non-null  category
#  4   Rndrng_Prvdr_State_Abrvtn  146427 non-null  category
#  5   DRG_Cd                     146427 non-null  category
#  6   Avg_Mdcr_Pymt_Amt          146427 non-null  float64
#  7   RUCA_category              146427 non-null  category
#  8   drg_grouped                146427 non-null  category
# dtypes: category(8), float64(1)
# memory usage: 4.6 MB

# %%
target = 'Avg_Mdcr_Pymt_Amt'
cols = [target] + [col for col in df_2023.columns if col != target]
df_2023 = df_2023[cols]
df_2023.head()
# Out:
#       Avg_Mdcr_Pymt_Amt Rndrng_Prvdr_CCN            Rndrng_Prvdr_Org_Name  \
# 2000      115544.142860           010001  Southeast Health Medical Center
# 2001       35261.807692           010001  Southeast Health Medical Center
# 2002       25048.916667           010001  Southeast Health Medical Center
# 2003       32438.625000           010001  Southeast Health Medical Center
# 2004        9579.363636           010001  Southeast Health Medical Center
#
#      Rndrng_Prvdr_City Rndrng_Prvdr_Zip5 Rndrng_Prvdr_State_Abrvtn DRG_Cd  \
# 2000            Dothan           36301.0                        AL    003
# 2001            Dothan           36301.0                        AL    023
# 2002            Dothan           36301.0                        AL    024
# 2003            Dothan           36301.0                        AL    025
# 2004            Dothan           36301.0                        AL    038
#
#            RUCA_category drg_grouped
# 2000  metro_high_commute         003
# 2001  metro_high_commute         023
# 2002  metro_high_commute         024
# 2003  metro_high_commute         025
# 2004  metro_high_commute         038

# %%
# 5% random sample of the full dataset
df_sampled = df_2023.sample(frac=0.05, random_state=42)
df_sampled
# Out:
#         Avg_Mdcr_Pymt_Amt Rndrng_Prvdr_CCN  \
# 2980          8826.280000           010039
# 110234        3652.666667           100315
# 110588       21010.800000           110001
# 185626       26276.583333           210043
# 257278        8260.636364           310050
# ...                   ...              ...
# 368937        5235.333333           440059
# 218913        5654.418605           240057
# 368799        5661.757576           440050
# 347420        5743.490196           390195
# 164406        3596.705882           180001
#
#                            Rndrng_Prvdr_Org_Name Rndrng_Prvdr_City  \
# 2980                         Huntsville Hospital        Huntsville
# 110234                            Viera Hospital         Melbourne
# 110588                   Hamilton Medical Center            Dalton
# 185626  Umd Baltimore Washington  Medical Center       Glen Burnie
# 257278                    Saint Clare's Hospital          Denville
# ...                                          ...               ...
# 368937        Cookeville Regional Medical Center        Cookeville
# 218913              Abbott Northwestern Hospital       Minneapolis
# 368799            Greeneville Community Hospital       Greeneville
# 347420                   Lankenau Medical Center         Wynnewood
# 164406                    St Elizabeth Ft Thomas       Fort Thomas
#
#        Rndrng_Prvdr_Zip5 Rndrng_Prvdr_State_Abrvtn DRG_Cd RUCA_category  \
# 2980             35801.0                        AL    602    metro_core
# 110234           32940.0                        FL    948    metro_core
# 110588           30720.0                        GA    521    metro_core
# 185626           21061.0                        MD    035    metro_core
# 257278            7834.0                        NJ    074    metro_core
# ...                  ...                       ...    ...           ...
# 368937           38501.0                        TN    065    micro_core
# 218913           55407.0                        MN    683    metro_core
# 368799           37745.0                        TN    872    micro_core
# 347420           19096.0                        PA    690    metro_core
# 164406           41075.0                        KY    948    metro_core
#
#        drg_grouped
# 2980           602
# 110234         948
# 110588         521
# 185626         035
# 257278         074
# ...            ...
# 368937         065
# 218913         683
# 368799         872
# 347420         690
# 164406         948
#
# [7321 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split

# Split into train/val/test
train_val, test = train_test_split(df_sampled, test_size=0.15, random_state=42)
train, val = train_test_split(train_val, test_size=0.15, random_state=42)

# Save to CSV for SageMaker (no headers, no index)
train.to_csv("train.csv", index=False, header=False)
val.to_csv("val.csv", index=False, header=False)
test.to_csv("test.csv", index=False, header=False)

# %%
train.head()
# Out:
#         Avg_Mdcr_Pymt_Amt Rndrng_Prvdr_CCN              Rndrng_Prvdr_Org_Name  \
# 251154        8803.666667           310011  Cape Regional Medical Center, Inc
# 347384       13428.642857           390195            Lankenau Medical Center
# 287764       12055.657895           330332                 St Joseph Hospital
# 395783       21941.461538           450686          University Medical Center
# 227332       18942.066667           250138            Merit Health River Oaks
#
#            Rndrng_Prvdr_City Rndrng_Prvdr_Zip5 Rndrng_Prvdr_State_Abrvtn  \
# 251154  Cape May Court House            8210.0                        NJ
# 347384             Wynnewood           19096.0                        PA
# 287764              Bethpage           11714.0                        NY
# 395783               Lubbock           79415.0                        TX
# 227332               Flowood           39232.0                        MS
#
#        DRG_Cd RUCA_category drg_grouped
# 251154    193    metro_core         193
# 347384    331    metro_core         331
# 287764    698    metro_core         698
# 395783    246    metro_core         246
# 227332    246    metro_core         246
